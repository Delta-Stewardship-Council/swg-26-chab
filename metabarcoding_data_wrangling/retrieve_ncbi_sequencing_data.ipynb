# %% [markdown]
# # Reproducible workflow for retrieving high-throughput sequencing data from NCBI "GenBank" using SRA Tools (not available in R)

# %%
import os

# Define project ID
bioproject = "PRJNA1458311" # Study "Study: Use of Multiple Sampling Modalities for Cyanobacteria and Cyanotoxin Monitoring in the Sacramento-San Joaquin Delta under Different Hydrologic Regimes"
output_dir = "sra_data"
os.makedirs(output_dir, exist_ok=True)
